# %% [markdown]
# # Visualizing Earnings Based On College Majors

# %% [markdown]
# |  Column Name   | Meaning  |
# |  :---------:   | :---------:   |
# |Rank | Rank by median earnings (the dataset is ordered by this column) |
# Major_code | Major code.
# Major | Major description.
# Major_category | Category of major.
# Total | Total number of people with major.
# Sample_size | Sample size (unweighted) of full-time.
# Men | Male graduates.
# Women | Female graduates.
# ShareWomen | Women as share of total.
# Employed | Number employed.
# Median | Median salary of full-time, year-round workers.
# Low_wage_jobs |Number in low-wage service jobs.
# Full_time| Number employed 35 hours or more.
# Part_time | Number employed less than 35 hours.

# %% [markdown]
# ## Introduction

# %%
import pandas as pd
import matplotlib.pyplot as plt
# make plots displayed inline.
# %matplotlib inline

# %%
# read dataset
recent_grads = pd.read_csv("recent-grads.csv")
recent_grads_head = recent_grads.iloc[0]
print(recent_grads.head())
print(recent_grads.tail())
recent_grads.describe()
# Out:
#    Rank  Major_code                                      Major    Total  \
# 0     1        2419                      PETROLEUM ENGINEERING   2339.0
# 1     2        2416             MINING AND MINERAL ENGINEERING    756.0
# 2     3        2415                  METALLURGICAL ENGINEERING    856.0
# 3     4        2417  NAVAL ARCHITECTURE AND MARINE ENGINEERING   1258.0
# 4     5        2405                       CHEMICAL ENGINEERING  32260.0
#
#        Men    Women Major_category  ShareWomen  Sample_size  Employed  \
# 0   2057.0    282.0    Engineering    0.120564           36      1976
# 1    679.0     77.0    Engineering    0.101852            7       640
# 2    725.0    131.0    Engineering    0.153037            3       648
# 3   1123.0    135.0    Engineering    0.107313           16       758
# 4  21239.0  11021.0    Engineering    0.341631          289     25694
#
#        ...        Part_time  Full_time_year_round  Unemployed  \
# ...

# %%
# drop missing values
raw_data_count = recent_grads.shape[0]
recent_grads = recent_grads.dropna()

# %%
raw_data_count
# Out:
# 173

# %%
cleaned_data_count = recent_grads.shape[0]
cleaned_data_count
# Out:
# 172

# %% [markdown]
# ## Pandas, Scatter Plots
#
# Using scatter plots to answer questions below:
# - Do students in more popular majors make more money?
# - Do students that majored in subjects that were majority female make more money?
# - Is there any link between the number of full-time employees and median salary?

# %%
recent_grads.plot(x="Sample_size",y="Median",kind="scatter")
# Out:
# <AxesSubplot:xlabel='Sample_size', ylabel='Median'>

# %%
recent_grads.plot(x="Sample_size",y="Unemployment_rate",kind="scatter")
# Out:
# <AxesSubplot:xlabel='Sample_size', ylabel='Unemployment_rate'>

# %%
recent_grads.plot(x="Full_time",y="Median",kind="scatter")
# Out:
# <AxesSubplot:xlabel='Full_time', ylabel='Median'>

# %%
recent_grads.plot(x="ShareWomen",y="Unemployment_rate",kind="scatter")
# Out:
# <AxesSubplot:xlabel='ShareWomen', ylabel='Unemployment_rate'>

# %%
recent_grads.plot(x="Men",y="Median",kind="scatter")
# Out:
# <AxesSubplot:xlabel='Men', ylabel='Median'>

# %%
recent_grads.plot(x="Women",y="Median",kind="scatter")
# Out:
# <AxesSubplot:xlabel='Women', ylabel='Median'>

# %% [markdown]
# 1. There is a weak positive correlation between major's popularity and earning.
# 2. There is a weak positive correlation between the women's proportion of major and earning.
# 3. positive weak correlation.

# %% [markdown]
# ## Pandas, Histograms

# %%
recent_grads["Sample_size"].hist()
# Out:
# <AxesSubplot:>

# %%
recent_grads["Median"].hist()
# Out:
# <AxesSubplot:>

# %%
recent_grads["Employed"].hist()
# Out:
# <AxesSubplot:>

# %%
recent_grads["Full_time"].hist()
# Out:
# <AxesSubplot:>

# %%
recent_grads["ShareWomen"].hist(bins=5)
# Out:
# <AxesSubplot:>

# %%
recent_grads["Unemployment_rate"].hist()
# Out:
# <AxesSubplot:>

# %%
recent_grads["Men"].hist()
# Out:
# <AxesSubplot:>

# %%
recent_grads["Women"].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Pandas, Scatter Matrix Plot

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize=(10,10))
# Out:
# Y:\APPLICATION\Anaconda3\lib\site-packages\pandas\plotting\_tools.py:308: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# Y:\APPLICATION\Anaconda3\lib\site-packages\pandas\plotting\_tools.py:308: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# Y:\APPLICATION\Anaconda3\lib\site-packages\pandas\plotting\_tools.py:314: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# ...

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median','Unemployment_rate']], figsize=(15,15))
# Out:
# Y:\APPLICATION\Anaconda3\lib\site-packages\pandas\plotting\_tools.py:308: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# Y:\APPLICATION\Anaconda3\lib\site-packages\pandas\plotting\_tools.py:308: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# Y:\APPLICATION\Anaconda3\lib\site-packages\pandas\plotting\_tools.py:314: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# ...

# %% [markdown]
# ## Pandas, Bar Plots

# %%
recent_grads[:10].plot.bar(x='Major', y='ShareWomen',legend=False)
recent_grads[-10:].plot.bar(x='Major', y='ShareWomen',legend=False)
# Out:
# <AxesSubplot:xlabel='Major'>

# %%
recent_grads[:10].plot.bar(x='Major', y='Unemployment_rate',legend=False)
recent_grads[-10:].plot.bar(x='Major', y='Unemployment_rate',legend=False)
# Out:
# <AxesSubplot:xlabel='Major'>

# %% [markdown]
# ## Use a grouped bar plot to compare the number of men with the number of women in each category of majors.

# %%
major_categories = recent_grads['Major_category'].unique()
major_categ_total_men_women = []
for major_cat in major_categories:
    sum_men = recent_grads.loc[recent_grads['Major_category'] == major_cat, 'Men'].sum()
    sum_women = recent_grads.loc[recent_grads['Major_category'] == major_cat, 'Women'].sum()
    major_total = (major_cat, sum_men, sum_women)
    major_categ_total_men_women.append(major_total)
men_women_cat_major = pd.DataFrame(major_categ_total_men_women, columns = ['Major_category', 'Total_Men', 'Total_Women'])
men_women_cat_major
# Out:
#                          Major_category  Total_Men  Total_Women
# 0                           Engineering   408307.0     129276.0
# 1                              Business   667852.0     634524.0
# 2                     Physical Sciences    95390.0      90089.0
# 3                   Law & Public Policy    91129.0      87978.0
# 4               Computers & Mathematics   208725.0      90283.0
# 5   Industrial Arts & Consumer Services   103781.0     126011.0
# 6                                  Arts   134390.0     222740.0
# 7                                Health    75517.0     387713.0
# 8                        Social Science   256834.0     273132.0
# 9                Biology & Life Science   184919.0     268943.0
# 10                            Education   103526.0     455603.0
# 11      Agriculture & Natural Resources    40357.0      35263.0
# 12            Humanities & Liberal Arts   272846.0     440622.0
# 13             Psychology & Social Work    98115.0     382892.0
# ...

# %%
men_women_cat_major.plot.bar(x="Major_category",y=["Total_Men", "Total_Women"])
# Out:
# <AxesSubplot:xlabel='Major_category'>

# %% [markdown]
# ## Use a box plot to explore the distributions of median salaries and unemployment rate.

# %%
data = recent_grads[["Median"]]
boxplot = data.boxplot(grid=False)
boxplot.set_title('Distribution of Median Salary')
# Out:
# Text(0.5, 1.0, 'Distribution of Median Salary')

# %%
data = recent_grads[["Unemployment_rate"]]
boxplot = data.boxplot(grid=False)
boxplot.set_title('Distribution of Unemployment rate')
# Out:
# Text(0.5, 1.0, 'Distribution of Unemployment rate')

# %% [markdown]
# ## Use a hexagonal bin plot to visualize the columns that had dense scatter plots from earlier in the project.

# %%
recent_grads.plot.hexbin(x="Sample_size",y="Median",gridsize=20)
# Out:
# Y:\APPLICATION\Anaconda3\lib\site-packages\pandas\plotting\_tools.py:308: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# Y:\APPLICATION\Anaconda3\lib\site-packages\pandas\plotting\_tools.py:308: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# Y:\APPLICATION\Anaconda3\lib\site-packages\pandas\plotting\_tools.py:314: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# ...

# %%
recent_grads.plot.hexbin(x='ShareWomen', y= 'Unemployment_rate', C='Median', gridsize=20)
# Out:
# Y:\APPLICATION\Anaconda3\lib\site-packages\pandas\plotting\_tools.py:308: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# Y:\APPLICATION\Anaconda3\lib\site-packages\pandas\plotting\_tools.py:308: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# Y:\APPLICATION\Anaconda3\lib\site-packages\pandas\plotting\_tools.py:314: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# ...
